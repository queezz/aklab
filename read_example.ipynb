# %%
#from aklab.qulee import QMS
# %run "aklab/qulee.py"
#qms = QMS('./data/S1_200805_212915.CSV')
qms = QMS('./data/S1_200804_200905.CSV')

# %%
# %matplotlib inline
import matplotlib.pylab as plt

# %%
qms.plot(figsize=[4,3])
axs = plt.gcf().get_axes()
axs[0].legend(bbox_to_anchor=(1,1.1))
